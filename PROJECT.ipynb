# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from tqdm import tqdm
import warnings

plt.style.use("fivethirtyeight")
warnings.filterwarnings("ignore")

# %%
# !pip install kaggle

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()  # Upload your CSV file
movies_md  = pd.read_csv('credits.csv', encoding='latin-1') # Specify encoding as 'latin-1'
# If 'latin-1' doesn't work, try other encodings like 'ISO-8859-1', 'cp1252', etc.
movies_md.head()
# Now you can use movies_md
print(movies_md.isnull().sum()) # Changed df to movies_md
# Out:
#      <input type="file" id="files-b2662e8b-2dc9-4f45-9cd3-b0f297089627" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2662e8b-2dc9-4f45-9cd3-b0f297089627">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
movies_md.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
movies_md.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    499 non-null    object
#  1   crew    499 non-null    object
#  2   id      499 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 11.8+ KB

# %%
import pandas as pd
from google.colab import files

# Upload the keywords.csv file
uploaded = files.upload()

# Now read the file
movies_keywords = pd.read_csv('keywords.csv', encoding='latin-1')

# Now you can use movies_keywords
movies_keywords.head()
# Out:
#      <input type="file" id="files-2a6ce2ef-60d2-4f0d-bbc2-72fbbf2fefc8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a6ce2ef-60d2-4f0d-bbc2-72fbbf2fefc8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
movies_md.head()  # Changed 'movies_credits' to 'movies_md'
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
movies_md.columns
# Out:
# Index(['cast', 'crew', 'id'], dtype='object')

# %%
movies_md.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()  # Upload your CSV file
movies_md  = pd.read_csv('credits.csv', encoding='latin-1') # Specify encoding as 'latin-1'
# If 'latin-1' doesn't work, try other encodings like 'ISO-8859-1', 'cp1252', etc.
movies_md.head()
# Now you can use movies_md
print(movies_md.isnull().sum()) # Changed df to movies_md
# Out:
#      <input type="file" id="files-0e59d0a6-c4d9-4898-b286-6be7f65426c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e59d0a6-c4d9-4898-b286-6be7f65426c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
len(movies_md)
# Out:
# 499

# %%
movies_md = movies_md[movies_md['id'].str.isnumeric()]

# %%
len(movies_md)
